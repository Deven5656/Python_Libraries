# %% [markdown]
# """<br>
#     @Author: Deven Gupta<br>
#     @Date: 13-08-2024<br>
#     @Last Modified by: Deven Gupta<br>
#     @Last Modified time: 13-08-2024<br>
#     @Title : Python program to Swarm plot using seaborn.<br>
#     <br>
# """

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Write a program to draw a swarm plot of total bill against size for a given dataset
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
def main():

    df = sns.load_dataset('tips').head(50)
    print(df.head(10))

    # sns.stripplot(data=df,x='total_bill',y='size',native_scale=True,color='green',size=5)

    sns.swarmplot(data=df,x='total_bill',y='size',native_scale=True,color='green',size=10)
    plt.show()


if __name__ == "__main__":
    main()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# ## 2. Write a program to draw swarm plot of “total bill” against day for a dataset given in url
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
def main():

    df = sns.load_dataset('tips')
    print(df.head())

    sns.swarmplot(data=df,x='total_bill',y='day',color='green')
    plt.show()


if __name__ == "__main__":
    main()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
