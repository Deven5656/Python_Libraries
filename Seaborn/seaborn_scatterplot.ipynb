# %% [markdown]
# """<br>
#     @Author: Deven Gupta<br>
#     @Date: 13-08-2024<br>
#     @Last Modified by: Deven Gupta<br>
#     @Last Modified time: 13-08-2024<br>
#     @Title : Python program to scatter plot using seaborn.<br>
#     <br>
# """

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Write a program to draw a scatter plot of “day” against “total bill” for a dataset given in a url
#
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
def main():
    url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

    df = pd.read_csv(url)
    print(df.head())

    sns.scatterplot(data=df,x='day',y='total_bill',c='green',edgecolor='r',s=50)
    plt.show()


if __name__ == "__main__":
    main()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
