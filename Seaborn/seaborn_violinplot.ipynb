# %% [markdown]
# """<br>
#     @Author: Deven Gupta<br>
#     @Date: 13-08-2024<br>
#     @Last Modified by: Deven Gupta<br>
#     @Last Modified time: 13-08-2024<br>
#     @Title : Python program to scatter plot using seaborn.<br>
#     <br>
# """

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1. Write a program to draw a violin plot of sex against total_bill for a given dataset
# https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv

# %%
def main():
    url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/tips.csv"

    df = pd.read_csv(url)
    print(df.head())

    sns.violinplot(data=df,x='sex',y='total_bill',color='green',edgecolor='r')
    plt.show()


if __name__ == "__main__":
    main()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## 2. Write a program to draw a violin plot of “species” against “sepal length” for a dataset given in a url
# https://github.com/mwaskom/seaborn-data/blob/master/iris.csv

# %%
def main():
    url="https://raw.githubusercontent.com/mwaskom/seaborn-data/master/iris.csv"

    df = pd.read_csv(url)
    print(df.head())

    sns.violinplot(data=df,x='species',y='sepal_length',color='green')
    plt.show()


if __name__ == "__main__":
    main()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa
